# %% [markdown]
# # Prepare Corridor data

# %%
# %matplotlib widget
import utils

# %% [markdown]
# ## Load data into Python and save it

# %%
cameras, measurements, points = utils.load_corridor_or_house_models(corridor=True)

utils.save_cameras("corridor/cameras.bin", cameras)
utils.save_measurements("corridor/measurements.bin", measurements)
utils.save_points("corridor/points.bin", points)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
